# %% [markdown]
# # OpenAI API 사전 준비

# %%
# 패키지 설치
# !pip install openai==0.28

# %%
# 환경변수 준비
import os
os.environ["OPENAI_API_KEY"] = ""

# %% [markdown]
# # 텍스트에서 이미지 생성

# %%
# 프롬프트 준비
prompt = "cat dancing on car"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import openai

# 텍스트에서 이미지 생성 실행
response = openai.Image.create(
    prompt=prompt,
    n=1,
    size="512x512"
)
image_url = response["data"][0]["url"]
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-PLIHvIZaN5qBCns42JU7An4M/user-xJC0K4vwANawuzVN4GaJONUw/img-q3nd2gI6nNLbRvRwOEOBZoxv.png?st=2024-06-25T01%3A21%3A33Z&se=2024-06-25T03%3A21%3A33Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-06-24T16%3A49%3A39Z&ske=2024-06-25T16%3A49%3A39Z&sks=b&skv=2023-11-03&sig=1mQmJ1ayy7aws1CzL0kFrPJZsYEFTwW5xmQB89xW3Do%3D

# %%
print(response)

# %% [markdown]
# # 기존 이미지의 변형 생성

# %%
# 이미지와 마스크 준비(현재 폴더에 이미지와 마스크를 넣어 둡니다)
image = open("image.png", "rb")
mask = open("mask.png", "rb")

# %%
import openai

# 이미지와 텍스트에서 이미지 편집을 실행
response = openai.Image.create_edit(
  image=image,
  mask=mask,
  prompt="many dogs in cardboard box",
  n=1,
  size="512x512"
)
image_url = response["data"][0]["url"]
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-PLIHvIZaN5qBCns42JU7An4M/user-xJC0K4vwANawuzVN4GaJONUw/img-N6jGwzkOEr8qeCCwtGWl8hNh.png?st=2024-06-25T03%3A15%3A29Z&se=2024-06-25T05%3A15%3A29Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-06-24T16%3A55%3A22Z&ske=2024-06-25T16%3A55%3A22Z&sks=b&skv=2023-11-03&sig=2yUfGmKOm6HnqjSsRrxvpV9s%2BxaUy/0pGq0eho8wiiQ%3D

# %%
print(response)

# %%
# 이미지 준비(현재 폴더에 이미지를 넣어 둡니다.)
image = open("/content/drive/MyDrive/Colab Notebooks/배울랑교(llm)/openai-llm-main/openai-llm-main/4_openai_api/image.png", "rb")

# %%
import openai

# 이미지에서 변형 생성
response = openai.Image.create_variation(
  image=image,
  n=1,
  size="512x512"
)
image_url = response["data"][0]["url"]
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-PLIHvIZaN5qBCns42JU7An4M/user-xJC0K4vwANawuzVN4GaJONUw/img-R7oUbmmb4ZkmQPRpyJmYoEUS.png?st=2024-06-25T03%3A26%3A42Z&se=2024-06-25T05%3A26%3A42Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-06-24T16%3A53%3A03Z&ske=2024-06-25T16%3A53%3A03Z&sks=b&skv=2023-11-03&sig=KYtVXB7EqRTt6wvdk3rC4KbDowBYKR%2Bfuqwsg/ACPog%3D

# %%
print(response)
